# %%
# !pip install tensorflow
# !pip install matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\vhsch\tf-env\lib\site-packages (2.19.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: setuptools in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (1.73.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: packaging in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\vhsch\tf-env\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vhsch\tf-env\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\vhsch\tf-env\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: optree in c:\users\vhsch\tf-env\lib\site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: namex in c:\users\vhsch\tf-env\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vhsch\tf-env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vhsch\tf-env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vhsch\tf-env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vhsch\tf-env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\vhsch\tf-env\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vhsch\tf-env\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vhsch\tf-env\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vhsch\tf-env\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vhsch\tf-env\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vhsch\tf-env\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vhsch\tf-env\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\vhsch\tf-env\lib\site-packages (3.10.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vhsch\tf-env\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\vhsch\tf-env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\vhsch\tf-env\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vhsch\tf-env\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: pillow>=8 in c:\users\vhsch\tf-env\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vhsch\tf-env\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vhsch\tf-env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vhsch\tf-env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vhsch\tf-env\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\vhsch\tf-env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import Sequential
from tensorflow.keras.losses import MeanSquaredError, BinaryCrossentropy
from tensorflow.keras.activations import sigmoid
from lab_utils_common import dlc
from lab_neurons_utils import plt_prob_1d, sigmoidnp, plt_linear, plt_logistic
plt.style.use('./deeplearning.mplstyle')
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

# %% [markdown]
# ### Neuron without activation - Regression/Linear Model

# %%
X_train =  np.array([[1.0], [2.0]], dtype=np.float32) 
Y_train = np.array([[300.0], [500.0]], dtype=np.float32)

# %%
fig, ax = plt.subplots(1,1)
ax.scatter(X_train, Y_train, marker = "x", c = "r", label = "Data Points")
ax.legend(fontsize = "xx-large")
ax.set_ylabel('Price (in 1000s of dollars)', fontsize='xx-large')
ax.set_xlabel('Size (1000 sqft)', fontsize='xx-large')
plt.show()

# %%
linear_layer = tf.keras.layers.Dense(units = 1, activation = "linear")

# %%
linear_layer.get_weights()
# Out:
# []

# %%
a1 = linear_layer(X_train[0].reshape(1,1))
print(a1)
# Out:
# tf.Tensor([[-0.15]], shape=(1, 1), dtype=float32)

# %%
w, b = linear_layer.get_weights()
print(f"w = {w}, b = {b}")
# Out:
# w = [[-0.15]], b = [0.]

# %%
set_w = np.array([[200]])
set_b = np.array([100])

#set weights takes a list of numpy arrays
linear_layer.set_weights([set_w, set_b])
print(linear_layer.get_weights())
# Out:
# [array([[200.]], dtype=float32), array([100.], dtype=float32)]

# %%
a1 = linear_layer(X_train[0].reshape(1,1))
print(a1)
alin = np.dot(set_w, X_train[0].reshape(1,1)) + set_b
print(alin)
# Out:
# tf.Tensor([[300.]], shape=(1, 1), dtype=float32)
# [[300.]]

# %%
prediction_tf = linear_layer(X_train)
prediction_np = np.dot(X_train, set_w) + b

# %%
plt_linear(X_train, Y_train, prediction_tf, prediction_np)

# %% [markdown]
# ### Neuron with Sigmoid Function

# %%
X_train = np.array([0., 1, 2, 3, 4, 5], dtype=np.float32).reshape(-1,1)  # 2-D Matrix
Y_train = np.array([0,  0, 0, 1, 1, 1], dtype=np.float32).reshape(-1,1)  # 2-D Matrix

# %%
pos = Y_train == 1
neg = Y_train == 0
X_train[pos]
# Out:
# array([3., 4., 5.], dtype=float32)

# %%
fig, ax = plt.subplots(1,1,figsize = (4,3))
ax.scatter(X_train[pos], Y_train[pos], marker = "x", s = 80, c = "red", label = "y=1")
ax.scatter(X_train[neg], Y_train[neg], marker = "o", s = 100, label = "y=0", facecolors = "none",
           edgecolors = dlc["dlblue"], lw = 3)
ax.set_ylim(-0.08,1.1)
ax.set_ylabel('y', fontsize=12)
ax.set_xlabel('x', fontsize=12)
ax.set_title('one variable plot')
ax.legend(fontsize=12)
plt.show()

# %%
model = Sequential(
    [
        tf.keras.layers.Dense(1, input_dim = 1, activation = "sigmoid", name = "L1")
    ]
)
# Out:
# C:\Users\vhsch\tf-env\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ L1 (Dense)                           │ (None, 1)                   │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
logistic_layer = model.get_layer("L1")
w, b = logistic_layer.get_weights()
print(w, b)
print(w.shape, b.shape)
# Out:
# [[-0.01]] [0.]
# (1, 1) (1,)

# %%
set_w = np.array([[2]])
set_b = np.array([-4.5])
# set_weights takes a list of numpy arrays
logistic_layer.set_weights([set_w, set_b])
print(logistic_layer.get_weights())
# Out:
# [array([[2.]], dtype=float32), array([-4.5], dtype=float32)]

# %%
a1 = model.predict(X_train[0].reshape(1,1))
print(a1)
alog = sigmoidnp(np.dot(set_w,X_train[0].reshape(1,1)) + set_b)
print(alog)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# [[0.01]]
# [[0.01]]

# %%
plt_logistic(X_train, Y_train, model, set_w, set_b, pos, neg)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
